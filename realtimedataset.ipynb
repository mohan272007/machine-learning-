# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('/content/drive/MyDrive/mlt/Copy of i1.csv')
df2=pd.read_csv('/content/drive/MyDrive/mlt/Copy of i2.csv')
df=df1.merge(df2,how='outer')

# %%
df.shape
# Out:
# (15621, 16)

# %%
df.head()
# Out:
#          Date            Timestamp  Invoice No.                    Item Name  \
# 0  2023-04-01  2023-04-01 13:16:03        23465          Babycorn Manchurian
# 1  2023-04-01  2023-04-01 13:16:03        23465            Chicken Kati Roll
# 2  2023-04-01  2023-04-01 13:16:03        23465         Paneer Butter Masala
# 3  2023-04-01  2023-04-01 13:16:03        23465                 Pulka (2 No)
# 4  2023-04-01  2023-04-01 13:16:03        23465  Schewan  Chicken Fried Rice
#
#    Price  Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
# 1  120.0   1.0      120.0       0.0   6.0        126.0       20.0      biller
# 2  150.0   2.0      300.0       0.0  15.0        315.0       20.0      biller
# 3   40.0   3.0      120.0       0.0   6.0        126.0       20.0      biller
# 4  160.0   1.0      160.0       0.0   8.0        168.0       20.0      biller
#
# ...

# %%
df.tail()
# Out:
#              Date            Timestamp  Invoice No.             Item Name  \
# 15616  2023-09-19  2023-09-19 22:03:44        28389                Kulcha
# 15617  2023-09-19  2023-09-19 22:03:44        28389         Mineral Water
# 15618  2023-09-19  2023-09-19 22:03:44        28389       Mushroom Masala
# 15619  2023-09-19  2023-09-19 22:03:44        28389  Paneer Butter Masala
# 15620  2023-09-19  2023-09-19 22:03:44        28389                Parota
#
#        Price  Qty.  Sub Total  Discount   Tax  Final Total  Table No.  \
# 15616   55.0   1.0       55.0       0.0  2.76        57.76       16.0
# 15617   20.0   2.0       40.0       0.0  2.00        42.00       16.0
# 15618  150.0   1.0      150.0       0.0  7.50       157.50       16.0
# 15619  150.0   1.0      150.0       0.0  7.50       157.50       16.0
# 15620   30.0   4.0      120.0       0.0  6.00       126.00       16.0
#
#       Server Name  Covers Variation             Category  HSN
# ...

# %%
df=df.drop(['Discount','Covers','Variation','Server Name','HSN'],axis=1)

# %%
df.shape
# Out:
# (15621, 11)

# %%
a=df['Final Total'].sum()

# %%
b=df['Invoice No.'].nunique()

# %%
aov=a/b

# %%
aov
# Out:
# np.float64(486.70256243654825)

# %%
m=df.groupby('Item Name')['Qty.'].sum().sort_values(ascending=False)[0:5]

# %%
sns.barplot(m)
# Out:
# <Axes: xlabel='Item Name', ylabel='Qty.'>

# %%
m.plot(kind='bar')
# Out:
# <Axes: xlabel='Item Name'>

# %%
df.groupby('Item Name')['Final Total'].sum().sort_values(ascending=False)[0:5]
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    240730.96
# Chicken Fried Rice                        119347.20
# Butter Naan                                65387.74
# Thandoor Chicken Half                      53185.83
# Paneer Butter Masala                       49581.22
# Name: Final Total, dtype: float64

# %%
df[df['Date']=='2023-09-15']['Final Total'].sum()
# Out:
# np.float64(21042.02)

# %%
df[df['Date']=='2023-09-15']
# Out:
#              Date            Timestamp  Invoice No.  \
# 15070  2023-09-15  2023-09-15 13:05:00        28222
# 15071  2023-09-15  2023-09-15 13:07:23        28223
# 15072  2023-09-15  2023-09-15 13:07:23        28223
# 15073  2023-09-15  2023-09-15 13:09:14        28224
# 15074  2023-09-15  2023-09-15 13:09:14        28224
# ...           ...                  ...          ...
# 15216  2023-09-15  2023-09-15 22:54:06        28262
# 15217  2023-09-15  2023-09-15 22:54:06        28262
# 15218  2023-09-15  2023-09-15 22:54:06        28262
# 15219  2023-09-15  2023-09-15 22:54:06        28262
# 15220  2023-09-15  2023-09-15 22:54:06        28262
#
#                                     Item Name  Price  Qty.  Sub Total  Tax  \
# 15070                          Veg Fried Rice  130.0   1.0      130.0  6.5
# 15071                    Butter Chicken Gravy  170.0   1.0      170.0  8.5
# 15072                      Romali Roti (1 No)   50.0   1.0       50.0  2.5
# ...

# %%
df[df['Date']=='2023-09-15']['Final Total']
# Out:
# 15070    136.5
# 15071    178.5
# 15072     52.5
# 15073     31.5
# 15074    168.0
#          ...
# 15216    136.5
# 15217     52.5
# 15218     21.0
# 15219    147.0
# 15220    157.5
# Name: Final Total, Length: 151, dtype: float64

# %%
df[(df['Date']=='2023-09-15') & (df['Item Name']=='Chicken Noodles')]['Qty.'].sum()
# Out:
# np.float64(7.0)

# %%
j=df.groupby('Invoice No.')['Final Total'].sum()
j[j>2000]
# Out:
# Invoice No.
# 23499     2533.64
# 23508     2011.00
# 23637     5644.82
# 23718     3517.50
# 23827    22638.00
#            ...
# 28014     3013.68
# 28126     2887.50
# 28145     4078.68
# 28259     4291.36
# 28315     2004.44
# Name: Final Total, Length: 162, dtype: float64

# %%
df[df['Final Total']==2887.50]['Invoice No.']
# Out:
# 14772    28126
# Name: Invoice No., dtype: int64

# %%
df[df['Invoice No.']==28145][['Item Name', 'Qty.', 'Final Total']].sum()
# Out:
# Item Name      Butter Chicken GravyButter Chicken GravyButter...
# Qty.                                                        40.0
# Final Total                                              4078.68
# dtype: object

# %%
from wordcloud import WordCloud
text = ' '.join(df['Item Name'].dropna().astype(str).values)
wordcloud = WordCloud(background_color='white',width=800,height=400).generate(text)

fig,ax=plt.subplots(figsize=(10,6))
ax.imshow(wordcloud,interpolation='lanczos')
ax.set_title('word column of item column')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
